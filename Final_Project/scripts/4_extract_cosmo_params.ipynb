# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/c170m_final_project
# Out:
# /content/drive/MyDrive/c170m_final_project

# %%
import glob, os
import yaml
import numpy as np
import pandas as pd

# %%
# Find number of files in directory
params_dir = "/content/drive/MyDrive/c170m_final_project"
list_plz = os.listdir(params_dir)

# %%
cosmo_params = np.genfromtxt("latin_hypercube_params.txt")
print(cosmo_params.shape)
# Out:
# (2000, 5)

# %%
df = pd.DataFrame(cosmo_params)
df.to_csv("/content/drive/MyDrive/c170m_final_project/void_data/latin_hypercube_params.csv")
